# %% [markdown]
# # Problem Statement:
#   #use the train data set and test data set
#   #For the Titanic challenge we need to guess whether the individuals from the test dataset had       survived or not.

# %% [markdown]
# # Import necessary library

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %% [markdown]
# # loading the train_dataset

# %%
df_train=pd.read_csv("C:/Users/SUHAS JADHAV/Desktop/SQL notes/train.csv")

# %% [markdown]
# # loading the test_dataset

# %%
df_test=pd.read_csv("C:/Users/SUHAS JADHAV/Desktop/SQL notes/test.csv")

# %% [markdown]
# # display  train_dataset the head and tail of the data set,info,describtion

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # display test_dataset the head and tail of the data set,info,describtion¶

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # checking null values in the train_data set

# %%
df_train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # from above i understand the Age and Cabin and Embarked contains null value for the better prediction i fill null values

# %% [markdown]
# # the data preprocessing step:filling the null values

# %%
train_data=df_train.fillna(method="ffill")

# %% [markdown]
# # after the filling the null value checking null values again

# %%
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %% [markdown]
# # checking null values in the test_data set

# %%
df_test.isnull()
# Out:
#      PassengerId  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0          False   False  False  False  False  False  False   False  False
# 1          False   False  False  False  False  False  False   False  False
# 2          False   False  False  False  False  False  False   False  False
# 3          False   False  False  False  False  False  False   False  False
# 4          False   False  False  False  False  False  False   False  False
# ..           ...     ...    ...    ...    ...    ...    ...     ...    ...
# 413        False   False  False  False   True  False  False   False  False
# 414        False   False  False  False  False  False  False   False  False
# 415        False   False  False  False  False  False  False   False  False
# 416        False   False  False  False   True  False  False   False  False
# 417        False   False  False  False   True  False  False   False  False
#
#      Cabin  Embarked
# 0     True     False
# 1     True     False
# ...

# %%
df_test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # from above i understand the Age and Cabin,fare  contains null value for the better prediction i fill null values

# %% [markdown]
# # the data preprocessing step:filling the null values

# %%
test_data=df_test.fillna(method="ffill")

# %%
test_data.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin          12
# Embarked        0
# dtype: int64

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # label Encoding: used to convert categorical columns into numerical ones so that they can be fitted by machine learning models which only take numerical data.

# %% [markdown]
# # # label encoding for train_dataset

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
train_data['Sex_type']=label_encoder.fit_transform(train_data["Sex"])
train_data['SibSp_type']=label_encoder.fit_transform(train_data["SibSp"])
train_data['Parch_type']=label_encoder.fit_transform(train_data["Parch"])
train_data['Fare_type']=label_encoder.fit_transform(train_data["Fare"])
train_data['Pclass_type']=label_encoder.fit_transform(train_data["Pclass"])
train_data['Age_type']=label_encoder.fit_transform(train_data["Age"])
train_data['Embarked_type']=label_encoder.fit_transform(train_data["Embarked"])

# %% [markdown]
# # # label encoding for test_dataset

# %%
test_data['Sex_type']=label_encoder.fit_transform(test_data["Sex"])
test_data['SibSp_type']=label_encoder.fit_transform(test_data["SibSp"])
test_data['Parch_type']=label_encoder.fit_transform(test_data["Parch"])
test_data['Fare_type']=label_encoder.fit_transform(test_data["Fare"])
test_data['Pclass_type']=label_encoder.fit_transform(test_data["Pclass"])
test_data['Age_type']=label_encoder.fit_transform(test_data["Age"])
test_data['Embarked_type']=label_encoder.fit_transform(test_data["Embarked"])

# %% [markdown]
# # prove to convert the categorical data into numerical one

# %%
train_data['Sex_type']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex_type, Length: 891, dtype: int32

# %%
test_data['Embarked_type']
# Out:
# 0      1
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 413    2
# 414    0
# 415    2
# 416    2
# 417    0
# Name: Embarked_type, Length: 418, dtype: int32

# %% [markdown]
# # for the accurate prediction delete unnecessary columns from both database

# %%
del train_data['PassengerId']
del train_data['Pclass']
del train_data['Age']
del train_data['Name']
del train_data['SibSp']
del train_data['Cabin']
del train_data['Parch']
del train_data['Fare']
del train_data['Ticket']
del train_data['Sex']
del train_data['Embarked']

# %%
train_data
# Out:
#      Survived  Sex_type  SibSp_type  Parch_type  Fare_type  Pclass_type  \
# 0           0         1           1           0         18            2
# 1           1         0           1           0        207            0
# 2           1         0           0           0         41            2
# 3           1         0           1           0        189            0
# 4           0         1           0           0         43            2
# ..        ...       ...         ...         ...        ...          ...
# 886         0         1           0           0         85            1
# 887         1         0           0           0        153            0
# 888         0         0           1           2        131            2
# 889         1         1           0           0        153            0
# 890         0         1           0           0         30            2
#
#      Age_type  Embarked_type
# 0          28              2
# 1          51              0
# ...

# %%
del test_data['PassengerId']
del test_data['Pclass']
del test_data['Age']
del test_data['Name']
del test_data['SibSp']
del test_data['Cabin']
del test_data['Parch']
del test_data['Fare']
del test_data['Ticket']
del test_data['Sex']
del test_data['Embarked']

# %%
test_data
# Out:
#      Sex_type  SibSp_type  Parch_type  Fare_type  Pclass_type  Age_type  \
# 0           1           0           0         24            2        44
# 1           0           1           0          5            2        60
# 2           1           0           0         41            1        74
# 3           1           0           0         34            2        34
# 4           0           1           1         46            2        27
# ..        ...         ...         ...        ...          ...       ...
# 413         1           0           0         31            2        35
# 414         0           0           0        154            0        51
# 415         1           0           0          9            2        50
# 416         1           0           0         31            2        50
# 417         1           1           1         84            2        50
#
#      Embarked_type
# 0                1
# 1                2
# 2                1
# 3                2
# ...

# %% [markdown]
# # Split into training and test set

# %%
#split the data into x and y
x=train_data[['Pclass_type', 'Age_type', 'SibSp_type','Parch_type', 'Fare_type', 'Embarked_type', 'Sex_type']]

y=train_data[['Survived']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %% [markdown]
# # scaling of X (train and test data) by using the standardization.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled = scaler.fit_transform(train_data)


x_train_scaled = scaler.fit_transform(x_train) 
x_test_scaled=scaler.transform(x_test)
print("Mean value:",x_train_scaled.mean(axis=0))
print("SD value:",x_train_scaled.std(axis=0))
# Out:
# Mean value: [-2.28103607e-17  9.97953281e-17  5.70259017e-17  0.00000000e+00
#   2.28103607e-17  1.14051803e-16 -8.83901477e-17]
# SD value: [1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# # Model selection and implimentation

# %%
from sklearn import tree
clf= tree.DecisionTreeClassifier()
clf= clf.fit(x_train_scaled,y_train)

# %% [markdown]
# # Accuracy Check by using standardization

# %%
clf.score(x_test_scaled,y_test)*100
# Out:
# 76.49253731343283

# %% [markdown]
# # scaling of X (train and test data) by using the normalization

# %%
from sklearn.preprocessing import Normalizer
scaler=Normalizer()
scaled = scaler.fit_transform(train_data)


x_train_scaled = scaler.fit_transform(x_train) 
x_test_scaled=scaler.transform(x_test)
print("Mean value:",x_train_scaled.mean(axis=0))
print("SD value:",x_train_scaled.std(axis=0))
# Out:
# Mean value: [0.02047739 0.43694862 0.00354254 0.00248258 0.82429863 0.01903787
#  0.0091942 ]
# SD value: [0.02052588 0.27530461 0.0069947  0.00567098 0.22810533 0.01695671
#  0.0103949 ]

# %%
from sklearn import tree
clf= tree.DecisionTreeClassifier()
clf= clf.fit(x_train_scaled,y_train)

# %%
from sklearn import tree
clf= tree.DecisionTreeClassifier()
clf= clf.fit(x_train_scaled,y_train)

# %% [markdown]
# # Accuracy Check by using Normalization

# %%
clf.score(x_test_scaled,y_test)*100
# Out:
# 73.13432835820896
